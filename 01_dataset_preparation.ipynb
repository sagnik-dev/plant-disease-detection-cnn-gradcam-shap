# %%
# !pip install opendatasets
import opendatasets as od
od.download("https://www.kaggle.com/datasets/emmarex/plantdisease")
# Out:
# ...
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: sagnikbiswas1
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/emmarex/plantdisease
# ...
# 100%|██████████| 658M/658M [00:01<00:00, 373MB/s]

# %%
import os

base_path = "/content/plantdisease/PlantVillage"  # change if needed

# Loop through each class folder
for folder in os.listdir(base_path):
    folder_path = os.path.join(base_path, folder)

    # Skip if not a directory
    if not os.path.isdir(folder_path):
        continue

    print(f"Renaming images inside: {folder}")

    # Loop through each image inside the folder
    for index, filename in enumerate(os.listdir(folder_path), start=1):
        file_path = os.path.join(folder_path, filename)

        # Extract file extension (.jpg, .png etc.)
        ext = os.path.splitext(filename)[1]

        # Create new filename → ClassName_001.jpg
        new_name = f"{folder}_{index}{ext}"
        new_path = os.path.join(folder_path, new_name)

        # Rename file
        os.rename(file_path, new_path)

print("✅ Renaming completed!")
# Out:
# Renaming images inside: Tomato_Leaf_Mold
# Renaming images inside: Tomato__Tomato_mosaic_virus
# Renaming images inside: Tomato_healthy
# Renaming images inside: Tomato__Tomato_YellowLeaf__Curl_Virus
# Renaming images inside: Tomato_Septoria_leaf_spot
# Renaming images inside: Potato___Early_blight
# Renaming images inside: Tomato__Target_Spot
# Renaming images inside: Tomato_Late_blight
# Renaming images inside: Potato___healthy
# Renaming images inside: Pepper__bell___Bacterial_spot
# Renaming images inside: Tomato_Spider_mites_Two_spotted_spider_mite
# Renaming images inside: Tomato_Early_blight
# Renaming images inside: Tomato_Bacterial_spot
# Renaming images inside: Pepper__bell___healthy
# Renaming images inside: Potato___Late_blight
# ✅ Renaming completed!
